# %% [markdown]
# ### Kod koji skida podatke sa sajta nekretnine.rs u csv fajl

# %%
# Importing relevant libraries 
import requests
from bs4 import BeautifulSoup
import csv
import time

# Base URL (without the page number, so we can iterate through every page)
BASE_URL = "https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/"

# Header so we wouldn't be blocked by the website 
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9"
}

# %%
# Main function for data scraping

def scrape_re(max_pages=5):
    listings = []  # Results

    for page in range(1, max_pages + 1):
        url = f"{BASE_URL}{page}/"
        print(f"Page number {page}: {url}")

        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Failed to access the page {page}. Status Code: {response.status_code}")
            break  # Breaks the function in case of error

        soup = BeautifulSoup(response.text, "html.parser")
        offers = soup.find_all("div", class_="row offer")

        print(f"Found {len(offers)} offers on page {page}")

        for offer in offers:
            try:
                # Title 
                title = offer.find("h2", class_="offer-title").get_text(strip=True)

                # Location
                location = offer.find("p", class_="offer-location").get_text(strip=True)

                # Price
                price_element = offer.find("p", class_="offer-price")
                price = price_element.find("span").get_text(strip=True) if price_element else "N/A"

                # Size
                size_element = offer.find("p", class_="offer-price--invert")
                size = size_element.find("span").get_text(strip=True) if size_element else "N/A"

                # Number of rooms
                type_element = offer.find("div", class_="mt-1 mt-lg-2 mb-lg-0 d-md-block offer-meta-info offer-adress")
                apartment_type = type_element.get_text(strip=True).split("|")[-1] if type_element else "N/A"

                # Saving to the list
                listings.append([title, location, price, size, apartment_type])

            except Exception as e:
                print(f"Error extracting offer: {e}")

        # Sleep to bypass blocking by the site
        time.sleep(2)

    # Saving the data to a csv file 
    with open("real_estate_raw.csv", "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Title", "Location", "Price", "Size", "Apartment Type"])
        writer.writerows(listings)

    print("Data scraping successful, saved in 'real_estate_raw.csv'.")

# %%
scrape_re(max_pages=200)
# Out:
# Page number 1: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/1/
# Found 49 offers on page 1
# Page number 2: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/2/
# Found 48 offers on page 2
# Page number 3: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/3/
# Found 50 offers on page 3
# Page number 4: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/4/
# Found 49 offers on page 4
# Page number 5: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/5/
# Found 50 offers on page 5
# Page number 6: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/6/
# Found 50 offers on page 6
# Page number 7: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/7/
# Found 48 offers on page 7
# Page number 8: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/8/
# Found 49 offers on page 8
# Page number 9: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/9/
# Found 50 offers on page 9
# Page number 10: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/10/
# Found 50 offers on page 10
# Page number 11: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/11/
# Found 50 offers on page 11
# Page number 12: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/12/
# Found 50 offers on page 12
# Page number 13: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/13/
# Found 50 offers on page 13
# Page number 14: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/14/
# Found 50 offers on page 14
# Page number 15: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/15/
# Found 50 offers on page 15
# Page number 16: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/16/
# Found 50 offers on page 16
# Page number 17: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/17/
# Found 50 offers on page 17
# Page number 18: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/18/
# Found 50 offers on page 18
# Page number 19: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/19/
# Found 50 offers on page 19
# Page number 20: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/20/
# Found 50 offers on page 20
# Page number 21: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/21/
# Found 50 offers on page 21
# Page number 22: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/22/
# Found 50 offers on page 22
# Page number 23: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/23/
# Found 50 offers on page 23
# Page number 24: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/24/
# Found 50 offers on page 24
# Page number 25: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/25/
# Found 50 offers on page 25
# Page number 26: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/26/
# Found 50 offers on page 26
# Page number 27: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/27/
# Found 50 offers on page 27
# Page number 28: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/28/
# Found 50 offers on page 28
# Page number 29: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/29/
# Found 50 offers on page 29
# Page number 30: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/30/
# Found 50 offers on page 30
# Page number 31: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/31/
# Found 50 offers on page 31
# Page number 32: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/32/
# Found 50 offers on page 32
# Page number 33: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/33/
# Found 50 offers on page 33
# Page number 34: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/34/
# Found 50 offers on page 34
# Page number 35: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/35/
# Found 50 offers on page 35
# Page number 36: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/36/
# Found 50 offers on page 36
# Page number 37: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/37/
# Found 50 offers on page 37
# Page number 38: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/38/
# Found 50 offers on page 38
# Page number 39: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/39/
# Found 50 offers on page 39
# Page number 40: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/40/
# Found 50 offers on page 40
# Page number 41: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/41/
# Found 50 offers on page 41
# Page number 42: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/42/
# Found 50 offers on page 42
# Page number 43: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/43/
# Found 50 offers on page 43
# Page number 44: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/44/
# Found 50 offers on page 44
# Page number 45: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/45/
# Found 49 offers on page 45
# Page number 46: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/46/
# Found 50 offers on page 46
# Page number 47: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/47/
# Found 50 offers on page 47
# Page number 48: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/48/
# Found 50 offers on page 48
# Page number 49: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/49/
# Found 50 offers on page 49
# Page number 50: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/50/
# Found 50 offers on page 50
# Page number 51: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/51/
# Found 50 offers on page 51
# Page number 52: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/52/
# Found 50 offers on page 52
# Page number 53: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/53/
# Found 50 offers on page 53
# Page number 54: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/54/
# Found 50 offers on page 54
# Page number 55: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/55/
# Found 50 offers on page 55
# Page number 56: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/56/
# Found 50 offers on page 56
# Page number 57: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/57/
# Found 50 offers on page 57
# Page number 58: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/58/
# Found 50 offers on page 58
# Page number 59: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/59/
# Found 50 offers on page 59
# Page number 60: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/60/
# Found 50 offers on page 60
# Page number 61: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/61/
# Found 50 offers on page 61
# Page number 62: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/62/
# Found 50 offers on page 62
# Page number 63: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/63/
# Found 50 offers on page 63
# Page number 64: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/64/
# Found 49 offers on page 64
# Page number 65: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/65/
# Found 50 offers on page 65
# Page number 66: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/66/
# Found 50 offers on page 66
# Page number 67: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/67/
# Found 50 offers on page 67
# Page number 68: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/68/
# Found 50 offers on page 68
# Page number 69: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/69/
# Found 50 offers on page 69
# Page number 70: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/70/
# Found 50 offers on page 70
# Page number 71: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/71/
# Found 50 offers on page 71
# Page number 72: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/72/
# Found 50 offers on page 72
# Page number 73: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/73/
# Found 50 offers on page 73
# Page number 74: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/74/
# Found 49 offers on page 74
# Page number 75: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/75/
# Found 50 offers on page 75
# Page number 76: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/76/
# Found 50 offers on page 76
# Page number 77: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/77/
# Found 50 offers on page 77
# Page number 78: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/78/
# Found 50 offers on page 78
# Page number 79: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/79/
# Found 50 offers on page 79
# Page number 80: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/80/
# Found 50 offers on page 80
# Page number 81: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/81/
# Found 50 offers on page 81
# Page number 82: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/82/
# Found 50 offers on page 82
# Page number 83: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/83/
# Found 50 offers on page 83
# Page number 84: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/84/
# Found 50 offers on page 84
# Page number 85: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/85/
# Found 48 offers on page 85
# Page number 86: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/86/
# Found 50 offers on page 86
# Page number 87: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/87/
# Found 50 offers on page 87
# Page number 88: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/88/
# Found 50 offers on page 88
# Page number 89: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/89/
# Found 50 offers on page 89
# Page number 90: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/90/
# Found 50 offers on page 90
# Page number 91: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/91/
# Found 50 offers on page 91
# Page number 92: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/92/
# Found 50 offers on page 92
# Page number 93: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/93/
# Found 50 offers on page 93
# Page number 94: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/94/
# Found 50 offers on page 94
# Page number 95: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/95/
# Found 50 offers on page 95
# Page number 96: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/96/
# Found 50 offers on page 96
# Page number 97: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/97/
# Found 50 offers on page 97
# Page number 98: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/98/
# Found 50 offers on page 98
# Page number 99: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/99/
# Found 50 offers on page 99
# Page number 100: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/100/
# Found 50 offers on page 100
# Page number 101: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/101/
# Found 50 offers on page 101
# Page number 102: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/102/
# Found 50 offers on page 102
# Page number 103: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/103/
# Found 50 offers on page 103
# Page number 104: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/104/
# Found 50 offers on page 104
# Page number 105: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/105/
# Found 50 offers on page 105
# Page number 106: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/106/
# Found 50 offers on page 106
# Page number 107: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/107/
# Found 50 offers on page 107
# Page number 108: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/108/
# Found 50 offers on page 108
# Page number 109: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/109/
# Found 50 offers on page 109
# Page number 110: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/110/
# Found 50 offers on page 110
# Page number 111: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/111/
# Found 50 offers on page 111
# Page number 112: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/112/
# Found 50 offers on page 112
# Page number 113: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/113/
# Found 50 offers on page 113
# Page number 114: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/114/
# Found 50 offers on page 114
# Page number 115: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/115/
# Found 50 offers on page 115
# Page number 116: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/116/
# Found 50 offers on page 116
# Page number 117: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/117/
# Found 50 offers on page 117
# Page number 118: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/118/
# Found 50 offers on page 118
# Page number 119: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/119/
# Found 50 offers on page 119
# Page number 120: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/120/
# Found 50 offers on page 120
# Page number 121: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/121/
# Found 50 offers on page 121
# Page number 122: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/122/
# Found 50 offers on page 122
# Page number 123: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/123/
# Found 50 offers on page 123
# Page number 124: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/124/
# Found 50 offers on page 124
# Page number 125: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/125/
# Found 50 offers on page 125
# Page number 126: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/126/
# Found 49 offers on page 126
# Page number 127: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/127/
# Found 50 offers on page 127
# Page number 128: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/128/
# Found 50 offers on page 128
# Page number 129: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/129/
# Found 50 offers on page 129
# Page number 130: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/130/
# Found 50 offers on page 130
# Page number 131: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/131/
# Found 50 offers on page 131
# Page number 132: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/132/
# Found 50 offers on page 132
# Page number 133: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/133/
# Found 50 offers on page 133
# Page number 134: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/134/
# Found 50 offers on page 134
# Page number 135: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/135/
# Found 50 offers on page 135
# Page number 136: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/136/
# Found 50 offers on page 136
# Page number 137: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/137/
# Found 50 offers on page 137
# Page number 138: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/138/
# Found 50 offers on page 138
# Page number 139: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/139/
# Found 50 offers on page 139
# Page number 140: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/140/
# Found 50 offers on page 140
# Page number 141: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/141/
# Found 50 offers on page 141
# Page number 142: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/142/
# Found 50 offers on page 142
# Page number 143: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/143/
# Found 50 offers on page 143
# Page number 144: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/144/
# Found 50 offers on page 144
# Page number 145: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/145/
# Found 50 offers on page 145
# Page number 146: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/146/
# Found 50 offers on page 146
# Page number 147: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/147/
# Found 50 offers on page 147
# Page number 148: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/148/
# Found 50 offers on page 148
# Page number 149: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/149/
# Found 50 offers on page 149
# Page number 150: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/150/
# Found 50 offers on page 150
# Page number 151: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/151/
# Found 50 offers on page 151
# Page number 152: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/152/
# Found 50 offers on page 152
# Page number 153: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/153/
# Found 50 offers on page 153
# Page number 154: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/154/
# Found 50 offers on page 154
# Page number 155: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/155/
# Found 50 offers on page 155
# Page number 156: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/156/
# Found 50 offers on page 156
# Page number 157: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/157/
# Found 50 offers on page 157
# Page number 158: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/158/
# Found 50 offers on page 158
# Page number 159: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/159/
# Found 50 offers on page 159
# Page number 160: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/160/
# Found 50 offers on page 160
# Page number 161: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/161/
# Found 50 offers on page 161
# Page number 162: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/162/
# Found 50 offers on page 162
# Page number 163: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/163/
# Found 50 offers on page 163
# Page number 164: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/164/
# Found 50 offers on page 164
# Page number 165: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/165/
# Found 50 offers on page 165
# Page number 166: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/166/
# Found 50 offers on page 166
# Page number 167: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/167/
# Found 50 offers on page 167
# Page number 168: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/168/
# Found 50 offers on page 168
# Page number 169: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/169/
# Found 50 offers on page 169
# Page number 170: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/170/
# Found 50 offers on page 170
# Page number 171: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/171/
# Found 50 offers on page 171
# Page number 172: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/172/
# Found 50 offers on page 172
# Page number 173: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/173/
# Found 50 offers on page 173
# Page number 174: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/174/
# Found 50 offers on page 174
# Page number 175: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/175/
# Found 50 offers on page 175
# Page number 176: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/176/
# Found 50 offers on page 176
# Page number 177: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/177/
# Found 49 offers on page 177
# Page number 178: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/178/
# Found 49 offers on page 178
# Page number 179: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/179/
# Found 50 offers on page 179
# Page number 180: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/180/
# Found 50 offers on page 180
# Page number 181: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/181/
# Found 50 offers on page 181
# Page number 182: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/182/
# Found 50 offers on page 182
# Page number 183: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/183/
# Found 50 offers on page 183
# Page number 184: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/184/
# Found 50 offers on page 184
# Page number 185: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/185/
# Found 50 offers on page 185
# Page number 186: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/186/
# Found 50 offers on page 186
# Page number 187: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/187/
# Found 50 offers on page 187
# Page number 188: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/188/
# Found 50 offers on page 188
# Page number 189: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/189/
# Found 50 offers on page 189
# Page number 190: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/190/
# Found 50 offers on page 190
# Page number 191: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/191/
# Found 50 offers on page 191
# Page number 192: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/192/
# Found 21 offers on page 192
# Page number 193: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/193/
# Found 0 offers on page 193
# Page number 194: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/194/
# Found 0 offers on page 194
# Page number 195: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/195/
# Found 0 offers on page 195
# Page number 196: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/196/
# Found 0 offers on page 196
# Page number 197: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/197/
# Found 0 offers on page 197
# Page number 198: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/198/
# Found 0 offers on page 198
# Page number 199: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/199/
# Found 0 offers on page 199
# Page number 200: https://www.nekretnine.rs/stambeni-objekti/stanovi/izdavanje-prodaja/prodaja/grad/beograd/lista/po-stranici/20/stranica/200/
# Found 0 offers on page 200
# Data scraping successful, saved in 'real_estate_raw.csv'.
